# %% [markdown]
# <a href="https://colab.research.google.com/github/yklise/YUNI/blob/main/apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install apyori

import pandas as pd
import numpy as np
from apyori import apriori
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5954 sha256=4f1d64ade27fcf25675c3fd38fd9a11984111483f858bb00d9ae216dcdbdb242
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# ...

# %%
df = pd.read_csv('/content/datasetApriorinew.csv')
df.head()
# Out:
#          day       time                 address       district accident_type  \
# 0     Friday      Night    perintis kemerdekaan     tamalanrea            TK
# 1     Sunday      Night  poros perumnas sudiang   biringkanaya            OC
# 2    Tuesday  Afternoon               sinassara          tallo            TK
# 3    Tuesday    Evening         sultan alauddin       tamalate            TM
# 4  Wednesday    Evening               karunrung  ujung pandang            TM
#
#           age gender suspect_vehicle       lat        long  Cluster
# 0  adolescent     PR              R2 -5.125716  119.504011        2
# 1  adolescent     LK              R2 -5.101811  119.531619        2
# 2  adolescent     LK              R2 -5.116897  119.439130        2
# 3       adult     PR              R2 -5.168213  119.420994        0
# 4  adolescent     LK              R2 -5.144885  119.412705        2

# %%
df.drop(["lat","long","Cluster"], axis="columns", inplace=True)
df.columns = ["day","time","address","district","accident_type","age","gender","suspect_vehicle"]
print(df.shape)
df.head()
# Out:
# (1338, 8)
#          day       time                 address       district accident_type  \
# 0     Friday      Night    perintis kemerdekaan     tamalanrea            TK
# 1     Sunday      Night  poros perumnas sudiang   biringkanaya            OC
# 2    Tuesday  Afternoon               sinassara          tallo            TK
# 3    Tuesday    Evening         sultan alauddin       tamalate            TM
# 4  Wednesday    Evening               karunrung  ujung pandang            TM
#
#           age gender suspect_vehicle
# 0  adolescent     PR              R2
# 1  adolescent     LK              R2
# 2  adolescent     LK              R2
# 3       adult     PR              R2
# 4  adolescent     LK              R2

# %%
records = []
for i in range(0,1338):
  records.append([str(df.values[i,j]) for j in range(0,8)])

records
# Out:
# [['Friday',
#   'Night',
#   'perintis kemerdekaan',
#   'tamalanrea',
#   'TK',
#   'adolescent',
#   'PR',
#   'R2'],
#  ['Sunday',
#   'Night',
#   'poros perumnas sudiang',
#   'biringkanaya',
#   'OC',
#   'adolescent',
#   'LK',
#   'R2'],
#  ['Tuesday',
#   'Afternoon',
#   'sinassara',
#   'tallo',
#   'TK',
#   'adolescent',
#   'LK',
#   'R2'],
#  ['Tuesday',
#   'Evening',
#   'sultan alauddin',
#   'tamalate',
#   'TM',
#   'adult',
#   'PR',
#   'R2'],
#  ['Wednesday',
#   'Evening',
#   'karunrung',
#   'ujung pandang',
#   'TM',
#   'adolescent',
#   'LK',
#   'R2'],
#  ['Thursday',
#   'Evening',
#   'veteran utara',
#   'makassar',
#   'TK',
#   'adolescent',
#   'LK',
#   'R6'],
#  ['Thursday',
#   'Afternoon',
#   'inspeksi pam',
#   'manggala',
#   'TK',
#   'adolescent',
#   'LK',
#   'R2'],
#  ['Monday', 'Evening', 'kumala', 'tamalate', 'TL', 'NOV', 'NOV', 'R2'],
#  ['Thursday',
#   'Afternoon',
#   'perintis kemerdekaan',
#   'biringkanaya',
#   'TK',
# ...

# %%
association_rule = apriori(records, min_support=0.0046, min_confidence=0.2, min_lift=3, min_length=2)

# %%
assoc_rule=list(association_rule)
assoc_rule
# Out:
# [RelationRecord(items=frozenset({'Night', 'R4'}), support=0.025411061285500747, ordered_statistics=[OrderedStatistic(items_base=frozenset({'R4'}), items_add=frozenset({'Night'}), confidence=0.6071428571428571, lift=3.1857142857142855)]),
#  RelationRecord(items=frozenset({'sunu', 'Sunday'}), support=0.005979073243647235, ordered_statistics=[OrderedStatistic(items_base=frozenset({'sunu'}), items_add=frozenset({'Sunday'}), confidence=0.4210526315789474, lift=3.2192481203007524)]),
#  RelationRecord(items=frozenset({'makassar', 'abu bakar lambogo'}), support=0.01046337817638266, ordered_statistics=[OrderedStatistic(items_base=frozenset({'abu bakar lambogo'}), items_add=frozenset({'makassar'}), confidence=1.0, lift=11.946428571428571)]),
# ...

# %%
for item in assoc_rule:
  pair = item[0]
  items = [x for x in pair]
  print(items)
  print("support: "+str(item[1]))

  print("confidance: "+str(item[2][0][2]))
  print("lift: "+str(item[2][0][3]))
  print("=========================================================")
# Out:
# Streaming output truncated to the last 5000 lines.
# ['TL', 'bontoala', 'LK', 'NOV']
# support: 0.011210762331838564
# confidance: 0.5172413793103448
# lift: 3.623397725221159
# ...
# ['TL', 'LK', 'NOV', 'makassar']
# support: 0.01195814648729447
# confidance: 0.4705882352941177
# lift: 3.4034976152623213
# ...
# ['TL', 'LK', 'NOV', 'manggala']
# support: 0.011210762331838564
# confidance: 0.45454545454545453
# lift: 3.2874692874692872
# ...
# ['TL', 'LK', 'NOV', 'mariso']
# support: 0.009715994020926755
# confidance: 0.5
# lift: 3.502617801047121
# ...
# ['TL', 'LK', 'NOV', 'panakkukang']
# support: 0.021674140508221227
# confidance: 0.4833333333333334
# lift: 3.3858638743455507
# ...
# ['TL', 'perintis kemerdekaan', 'LK', 'NOV']
# support: 0.008968609865470852
# confidance: 1.0
# lift: 3.6557377049180326
# ...
# ['TL', 'LK', 'NOV', 'rappocini']
# support: 0.01046337817638266
# confidance: 0.48275862068965514
# lift: 3.4915191053122085
# ...
# ['TL', 'LK', 'NOV', 'sultan alauddin']
# support: 0.005979073243647235
# ...
