# %% [markdown]
# <a href="https://colab.research.google.com/github/yklise/YUNI/blob/main/APRIORICOBAJA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install apyori

import pandas as pd
import numpy as np
from apyori import apriori
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ...

# %%
df = pd.read_csv('/content/SABAR.csv')
df.drop(["NO", "TGL"], axis="columns", inplace=True)
print("Columns after drop:", df.columns)
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Columns after drop: Index(['HARI', 'JAM', 'JALAN', 'KECAMATAN', 'JENIS KECELAKAAN', 'UMUR',
#        'JENIS KELAMIN', 'KENDARAAN TERSANGKA', 'KENDARAAN KORBAN'],
#       dtype='object')
#         HARI      JAM                 JALAN      KECAMATAN JENIS KECELAKAAN  \
# 0   Thursday  Evening             Abd KADIR       Tamalate               TK
# 1  Wednesday  Evening            IR. SUTAMI     Tamalanrea               TK
# 2   Saturday    Night            ANDI JEMMA      Rappocini               TK
# 3     Sunday    Night        BONTOLEMPANGAN  Ujung Pandang               TK
# ...

# %%
df.columns = ["day","time","address","district","accident_type","age","gender","suspect_vehicle","victim_vehicle"]
print(df.shape)
df.head()
# Out:
# (861, 9)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          day     time               address       district accident_type  \
# 0   Thursday  Evening             Abd KADIR       Tamalate            TK
# 1  Wednesday  Evening            IR. SUTAMI     Tamalanrea            TK
# 2   Saturday    Night            ANDI JEMMA      Rappocini            TK
# 3     Sunday    Night        BONTOLEMPANGAN  Ujung Pandang            TK
# 4     Monday  Morning  PERINTIS KEMERDEKAAN   Biringkanaya            TK
#
#           age gender suspect_vehicle victim_vehicle
# 0  adolescent     LK              R2            KR2
# 1       adult     LK              R2            KR4
# ...

# %%
df["address"] = df["address"].map(lambda x: str(x).strip().lower())
df["district"] = df["district"].map(lambda x: str(x).strip().lower())
df["gender"] = df["gender"].map(lambda x: str(x).strip().upper())
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          day     time               address       district accident_type  \
# 0   Thursday  Evening             abd kadir       tamalate            TK
# 1  Wednesday  Evening            ir. sutami     tamalanrea            TK
# 2   Saturday    Night            andi jemma      rappocini            TK
# 3     Sunday    Night        bontolempangan  ujung pandang            TK
# 4     Monday  Morning  perintis kemerdekaan   biringkanaya            TK
#
#           age gender suspect_vehicle victim_vehicle
# 0  adolescent     LK              R2            KR2
# 1       adult     LK              R2            KR4
# ...

# %%
df.drop(["address","district"], axis="columns", inplace=True)
df.columns = ["day","time","accident_type","age","gender","suspect_vehicle","victim_vehicle"]
print(df.shape)
df.head()
# Out:
# (861, 7)
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#          day     time accident_type         age gender suspect_vehicle  \
# 0   Thursday  Evening            TK  adolescent     LK              R2
# 1  Wednesday  Evening            TK       adult     LK              R2
# 2   Saturday    Night            TK       adult     LK              R4
# 3     Sunday    Night            TK       adult     LK              R2
# 4     Monday  Morning            TK  adolescent     PR              R2
#
#   victim_vehicle
# 0            KR2
# 1            KR4
# 2            KR4
# 3            KR3
# 4            KR2

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Membaca data dari file CSV
# df = pd.read_csv('nama_file.csv')

# Mengonversi data menjadi list of lists (transaksi)
transactions = df.values.tolist()

# Menggunakan TransactionEncoder untuk mengonversi data transaksi menjadi matriks biner
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_transformed = pd.DataFrame(te_ary, columns=te.columns_)

# Menjalankan algoritma Apriori untuk mendapatkan itemset yang sering muncul
frequent_itemsets = apriori(df_transformed, min_support=0.3, use_colnames=True)

# Menampilkan itemset yang sering muncul
print("Frequent Itemsets:")
print(frequent_itemsets)

# Menjalankan algoritma Association Rules untuk mendapatkan aturan asosiasi
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.8)

# Menampilkan aturan asosiasi
print("\nAssociation Rules:")
print(rules)
# Out:
# Frequent Itemsets:
#      support               itemsets
# 0   0.752613                  (KR2)
# 1   0.756098                   (LK)
# 2   0.362369              (Morning)
# 3   0.427410                (Night)
# 4   0.710801                   (R2)
# 5   1.000000                   (TK)
# 6   0.414634           (adolescent)
# 7   0.550523                (adult)
# 8   0.551684              (KR2, LK)
# 9   0.304297           (KR2, Night)
# 10  0.524971              (KR2, R2)
# 11  0.752613              (KR2, TK)
# 12  0.319396      (KR2, adolescent)
# 13  0.404181           (KR2, adult)
# 14  0.334495            (LK, Night)
# 15  0.548200               (R2, LK)
# 16  0.756098               (TK, LK)
# 17  0.315912       (adolescent, LK)
# 18  0.413473            (adult, LK)
# 19  0.362369          (TK, Morning)
# 20  0.427410            (TK, Night)
# 21  0.710801               (TK, R2)
# 22  0.331010       (R2, adolescent)
# 23  0.347271            (R2, adult)
# ...
